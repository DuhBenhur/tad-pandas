# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv('modelo_negocio - modelo_negocio.csv')

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Empresa                      0
# Caracteristica_negocio_1     0
# Caracteristica_negocio_2     0
# Caracteristica_negocio_3     0
# Caracteristica_negocio_4     0
# Caracteristica_negocio_5     0
# Caracteristica_negocio_6     0
# Caracteristica_negocio_7     0
# Caracteristica_negocio_8     0
# Caracteristica_negocio_9     0
# Caracteristica_negocio_10    0
# Cultura_1                    0
# Cultura_2                    0
# Cultura_3                    0
# Cultura_4                    0
# Cultura_5                    0
# Forma_organizacao_1          0
# Forma_organizacao_2          0
# Forma_organizacao_3          0
# Forma_organizacao_4          0
# Forma_organizacao_5          0
# Desen_Novo_Prod_1            0
# Desen_Novo_Prod_2            0
# Desen_Novo_Prod_3            0
# Desen_Novo_Prod_4            0
# Desen_Novo_Prod_5            0
# dtype: int64

# %%
df.dtypes
# Out:
# Empresa                      object
# Caracteristica_negocio_1      int64
# Caracteristica_negocio_2      int64
# Caracteristica_negocio_3      int64
# Caracteristica_negocio_4      int64
# Caracteristica_negocio_5      int64
# Caracteristica_negocio_6      int64
# Caracteristica_negocio_7      int64
# Caracteristica_negocio_8      int64
# Caracteristica_negocio_9      int64
# Caracteristica_negocio_10     int64
# Cultura_1                     int64
# Cultura_2                     int64
# Cultura_3                     int64
# Cultura_4                     int64
# Cultura_5                     int64
# Forma_organizacao_1           int64
# Forma_organizacao_2           int64
# Forma_organizacao_3           int64
# Forma_organizacao_4           int64
# Forma_organizacao_5           int64
# Desen_Novo_Prod_1             int64
# Desen_Novo_Prod_2             int64
# Desen_Novo_Prod_3             int64
# Desen_Novo_Prod_4             int64
# Desen_Novo_Prod_5             int64
# dtype: object

# %% [markdown]
# Correlação de Pearson

# %%
import seaborn as sns
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
df.describe()
# Out:
#        Caracteristica_negocio_1  Caracteristica_negocio_2  \
# count                 39.000000                 39.000000
# mean                   0.641026                  0.205128
# std                    0.485971                  0.409074
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    1.000000                  0.000000
# 75%                    1.000000                  0.000000
# max                    1.000000                  1.000000
#
#        Caracteristica_negocio_3  Caracteristica_negocio_4  \
# count                 39.000000                 39.000000
# mean                   0.538462                  0.307692
# std                    0.505035                  0.467572
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    1.000000                  0.000000
# 75%                    1.000000                  1.000000
# max                    1.000000                  1.000000
#
#        Caracteristica_negocio_5  Caracteristica_negocio_6  \
# count                 39.000000                      39.0
# mean                   0.179487                       0.0
# std                    0.388776                       0.0
# min                    0.000000                       0.0
# 25%                    0.000000                       0.0
# 50%                    0.000000                       0.0
# 75%                    0.000000                       0.0
# max                    1.000000                       0.0
#
#        Caracteristica_negocio_7  Caracteristica_negocio_8  \
# count                 39.000000                 39.000000
# mean                   0.076923                  0.230769
# std                    0.269953                  0.426833
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    0.000000                  0.000000
# max                    1.000000                  1.000000
#
#        Caracteristica_negocio_9  Caracteristica_negocio_10        ...          \
# count                 39.000000                  39.000000        ...
# mean                   0.128205                   0.102564        ...
# std                    0.338688                   0.307355        ...
# min                    0.000000                   0.000000        ...
# 25%                    0.000000                   0.000000        ...
# 50%                    0.000000                   0.000000        ...
# 75%                    0.000000                   0.000000        ...
# max                    1.000000                   1.000000        ...
#
#        Forma_organizacao_1  Forma_organizacao_2  Forma_organizacao_3  \
# count            39.000000            39.000000            39.000000
# mean              0.076923             0.333333             0.512821
# std               0.269953             0.477567             0.506370
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             1.000000
# 75%               0.000000             1.000000             1.000000
# max               1.000000             1.000000             1.000000
#
#        Forma_organizacao_4  Forma_organizacao_5  Desen_Novo_Prod_1  \
# count            39.000000            39.000000          39.000000
# mean              0.205128             0.102564           0.384615
# std               0.409074             0.307355           0.492864
# min               0.000000             0.000000           0.000000
# 25%               0.000000             0.000000           0.000000
# 50%               0.000000             0.000000           0.000000
# 75%               0.000000             0.000000           1.000000
# max               1.000000             1.000000           1.000000
#
#        Desen_Novo_Prod_2  Desen_Novo_Prod_3  Desen_Novo_Prod_4  \
# count          39.000000          39.000000          39.000000
# mean            0.256410           0.230769           0.128205
# std             0.442359           0.426833           0.338688
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.500000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        Desen_Novo_Prod_5
# count          39.000000
# mean            0.051282
# std             0.223456
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000
#
# [8 rows x 25 columns]

# %%
df2 = pd.read_csv('PCR - dados.csv')

# %%
df2.describe()
# Out:
#            GDNF       BDNF        TNF         PKR      SFRP1      TRPC6  \
# count  20.00000  20.000000  20.000000   20.000000  20.000000  20.000000
# mean    1.84810   0.459363   2.105000   12.961950   0.348950   2.192450
# std     2.43929   0.838219   3.020589   23.690927   0.648655   2.204562
# min     0.12300   0.000132   0.109000    0.332000   0.015000   0.242000
# 25%     0.38050   0.001000   0.244250    2.146250   0.045500   0.720750
# 50%     0.69200   0.004000   0.788500    3.604500   0.105000   1.326000
# 75%     2.68575   0.719250   2.597000   12.940250   0.362000   2.550750
# max    10.56700   2.583000  11.789000  104.893000   2.857000   8.848000
#
#            NR4A2      NR4A3     TIPARP
# count  20.000000  20.000000  20.000000
# mean    1.042600   3.155000   2.870400
# std     1.050132   5.021752   1.805885
# min     0.164000   0.528000   0.784000
# 25%     0.329750   1.101250   1.882500
# 50%     0.417500   1.501500   2.334500
# 75%     1.656500   2.178250   3.162250
# max     3.366000  20.687000   7.800000

# %% [markdown]
# Teste não paramétrico

# %%
from scipy.stats import mannwhitneyu, wilcoxon

# %%
mannwhitneyu(df2['TIPARP'].iloc[:10], df2['TIPARP'].iloc[10:])
# Out:
# MannwhitneyuResult(statistic=24.0, pvalue=0.026951278584693587)

# %%
wilcoxon(df2['TIPARP'].iloc[:10], df2['TIPARP'].iloc[10:])
# Out:
# WilcoxonResult(statistic=12.0, pvalue=0.11412832776223863)
